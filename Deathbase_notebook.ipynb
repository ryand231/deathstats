# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import glob

# %%
path = r'data/' # use your path
all_files = glob.glob(path + "/*.txt")
all_files
# Out:
# ['data\\deaths_19992000.txt',
#  'data\\deaths_20012002.txt',
#  'data\\deaths_20032004.txt',
#  'data\\deaths_20052006.txt',
#  'data\\deaths_20072008.txt',
#  'data\\deaths_20092010.txt',
#  'data\\deaths_20112012.txt',
#  'data\\deaths_20132014.txt',
#  'data\\deaths_20152016.txt',
#  'data\\deaths_20172018.txt']

# %%
li = []

for filename in all_files:

    df = pd.read_csv(filename, sep='\t', index_col=None, header=0)

    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
#df = pd.read_csv('data/deaths_20172018.txt', sep='\t') ## Reading a single file

# %%
frame.head(2)
# Out:
#   Notes               Census Region Census Region Code  \
# 0   NaN  Census Region 1: Northeast            CENS-R1
# 1   NaN  Census Region 1: Northeast            CENS-R1
#
#                                ICD-10 113 Cause List  \
# 0  Certain other intestinal infections (A04,A07-A09)
# 1  Certain other intestinal infections (A04,A07-A09)
#
#   ICD-10 113 Cause List Code    Year  Year Code Ten-Year Age Groups  \
# 0                  GR113-003  1999.0     1999.0         55-64 years
# 1                  GR113-003  1999.0     1999.0         65-74 years
#
#   Ten-Year Age Groups Code  Gender Gender Code  Deaths Population  Crude Rate
# 0                    55-64    Male           M    10.0    2240726  Unreliable
# 1                    65-74  Female           F    24.0    2112718         1.1

# %%
frame.tail(2)
# Out:
#                                                     Notes Census Region  \
# 124016  in information available to individual states ...           NaN
# 124017  information can be found at: https://www.cdc.g...           NaN
#
#        Census Region Code ICD-10 113 Cause List ICD-10 113 Cause List Code  \
# 124016                NaN                   NaN                        NaN
# 124017                NaN                   NaN                        NaN
#
#         Year  Year Code Ten-Year Age Groups Ten-Year Age Groups Code Gender  \
# 124016   NaN        NaN                 NaN                      NaN    NaN
# 124017   NaN        NaN                 NaN                      NaN    NaN
#
#        Gender Code  Deaths Population Crude Rate
# 124016         NaN     NaN        NaN        NaN
# 124017         NaN     NaN        NaN        NaN

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124018 entries, 0 to 124017
# Data columns (total 14 columns):
# Notes                         658 non-null object
# Census Region                 123360 non-null object
# Census Region Code            123360 non-null object
# ICD-10 113 Cause List         123360 non-null object
# ICD-10 113 Cause List Code    123360 non-null object
# Year                          123360 non-null float64
# Year Code                     123360 non-null float64
# Ten-Year Age Groups           123360 non-null object
# Ten-Year Age Groups Code      123360 non-null object
# Gender                        123360 non-null object
# Gender Code                   123360 non-null object
# Deaths                        123360 non-null float64
# Population                    123360 non-null object
# Crude Rate                    123360 non-null object
# dtypes: float64(3), object(11)
# memory usage: 8.0+ MB

# %%
# Drop an entire culumn , In this case 'Notes'
frame_no_nan = frame.drop(columns=['Notes'])

# %%
frame_no_nan.head(2)
# Out:
#                 Census Region Census Region Code  \
# 0  Census Region 1: Northeast            CENS-R1
# 1  Census Region 1: Northeast            CENS-R1
#
#                                ICD-10 113 Cause List  \
# 0  Certain other intestinal infections (A04,A07-A09)
# 1  Certain other intestinal infections (A04,A07-A09)
#
#   ICD-10 113 Cause List Code    Year  Year Code Ten-Year Age Groups  \
# 0                  GR113-003  1999.0     1999.0         55-64 years
# 1                  GR113-003  1999.0     1999.0         65-74 years
#
#   Ten-Year Age Groups Code  Gender Gender Code  Deaths Population  Crude Rate
# 0                    55-64    Male           M    10.0    2240726  Unreliable
# 1                    65-74  Female           F    24.0    2112718         1.1

# %%
# Get a list of unique values in the Year column
frame_no_nan['Year'].unique()
# Out:
# array([1999., 2000.,   nan, 2001., 2002., 2003., 2004., 2005., 2006.,
#        2007., 2008., 2009., 2010., 2011., 2012., 2013., 2014., 2015.,
#        2016., 2017., 2018.])

# %%
## Get the number of null values in the Year column
frame_no_nan['Year'].isnull().sum()
# Out:
# 658

# %%
#frame_no_nan.to_csv('death1999_2018.csv', encoding='utf-8')
frame_no_nan4.to_csv('data/death1999_2018v4.csv', encoding='utf-8')

# %%
frame_no_nan2 = frame_no_nan.dropna()

# %%
frame_no_nan2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123360 entries, 0 to 123953
# Data columns (total 13 columns):
# Census Region                 123360 non-null object
# Census Region Code            123360 non-null object
# ICD-10 113 Cause List         123360 non-null object
# ICD-10 113 Cause List Code    123360 non-null object
# Year                          123360 non-null float64
# Year Code                     123360 non-null float64
# Ten-Year Age Groups           123360 non-null object
# Ten-Year Age Groups Code      123360 non-null object
# Gender                        123360 non-null object
# Gender Code                   123360 non-null object
# Deaths                        123360 non-null float64
# Population                    123360 non-null object
# Crude Rate                    123360 non-null object
# dtypes: float64(3), object(10)
# memory usage: 8.5+ MB

# %%
frame_no_nan2.head(3)
# Out:
#                 Census Region Census Region Code  \
# 0  Census Region 1: Northeast            CENS-R1
# 1  Census Region 1: Northeast            CENS-R1
# 2  Census Region 1: Northeast            CENS-R1
#
#                                ICD-10 113 Cause List  \
# 0  Certain other intestinal infections (A04,A07-A09)
# 1  Certain other intestinal infections (A04,A07-A09)
# 2  Certain other intestinal infections (A04,A07-A09)
#
#   ICD-10 113 Cause List Code    Year  Year Code Ten-Year Age Groups  \
# 0                  GR113-003  1999.0     1999.0         55-64 years
# 1                  GR113-003  1999.0     1999.0         65-74 years
# 2                  GR113-003  1999.0     1999.0         65-74 years
#
#   Ten-Year Age Groups Code  Gender Gender Code  Deaths Population  Crude Rate
# 0                    55-64    Male           M    10.0    2240726  Unreliable
# 1                    65-74  Female           F    24.0    2112718         1.1
# ...

# %%
frame_no_nan2['Year'].isnull().sum()
# Out:
# 0

# %%
frame_no_nan2.head(3)
# Out:
#                 Census Region Census Region Code  \
# 0  Census Region 1: Northeast            CENS-R1
# 1  Census Region 1: Northeast            CENS-R1
# 2  Census Region 1: Northeast            CENS-R1
#
#                                ICD-10 113 Cause List  \
# 0  Certain other intestinal infections (A04,A07-A09)
# 1  Certain other intestinal infections (A04,A07-A09)
# 2  Certain other intestinal infections (A04,A07-A09)
#
#   ICD-10 113 Cause List Code    Year  Year Code Ten-Year Age Groups  \
# 0                  GR113-003  1999.0     1999.0         55-64 years
# 1                  GR113-003  1999.0     1999.0         65-74 years
# 2                  GR113-003  1999.0     1999.0         65-74 years
#
#   Ten-Year Age Groups Code  Gender Gender Code  Deaths Population  Crude Rate
# 0                    55-64    Male           M    10.0    2240726  Unreliable
# 1                    65-74  Female           F    24.0    2112718         1.1
# ...

# %%
frame_no_nan2['Ten-Year Age Groups Code'].unique()
# Out:
# array(['55-64', '65-74', '75-84', '85+', '45-54', '1', '1-4', '15-24',
#        '25-34', '35-44', '5-14', 'NS'], dtype=object)

# %%
frame_no_nan2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123360 entries, 0 to 123953
# Data columns (total 13 columns):
# Census Region                 123360 non-null object
# Census Region Code            123360 non-null object
# ICD-10 113 Cause List         123360 non-null object
# ICD-10 113 Cause List Code    123360 non-null object
# Year                          123360 non-null float64
# Year Code                     123360 non-null float64
# Ten-Year Age Groups           123360 non-null object
# Ten-Year Age Groups Code      123360 non-null object
# Gender                        123360 non-null object
# Gender Code                   123360 non-null object
# Deaths                        123360 non-null float64
# Population                    123360 non-null object
# Crude Rate                    123360 non-null object
# dtypes: float64(3), object(10)
# memory usage: 8.5+ MB

# %%
frame_no_nan3 = frame_no_nan2.drop(columns=['Census Region Code', 'Year Code', 'Ten-Year Age Groups Code', 'Gender Code'])

# %%
frame_no_nan3.head(5)
# Out:
#                 Census Region  \
# 0  Census Region 1: Northeast
# 1  Census Region 1: Northeast
# 2  Census Region 1: Northeast
# 3  Census Region 1: Northeast
# 4  Census Region 1: Northeast
#
#                                ICD-10 113 Cause List  \
# 0  Certain other intestinal infections (A04,A07-A09)
# 1  Certain other intestinal infections (A04,A07-A09)
# 2  Certain other intestinal infections (A04,A07-A09)
# 3  Certain other intestinal infections (A04,A07-A09)
# 4  Certain other intestinal infections (A04,A07-A09)
#
#   ICD-10 113 Cause List Code    Year Ten-Year Age Groups  Gender  Deaths  \
# 0                  GR113-003  1999.0         55-64 years    Male    10.0
# 1                  GR113-003  1999.0         65-74 years  Female    24.0
# 2                  GR113-003  1999.0         65-74 years    Male    20.0
# 3                  GR113-003  1999.0         75-84 years  Female    71.0
# 4                  GR113-003  1999.0         75-84 years    Male    51.0
#
# ...

# %%
frame_no_nan4 = frame_no_nan3.copy()

# %%
frame_no_nan4.drop(frame_no_nan4.index[frame_no_nan4['Crude Rate'] == 'Unreliable'], inplace = True)

# %%
frame_no_nan4.drop(frame_no_nan4.index[frame_no_nan4['Crude Rate'] == 'Not Applicable'], inplace = True)

# %%
frame_no_nan4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106070 entries, 0 to 106261
# Data columns (total 9 columns):
# Census Region                 106070 non-null object
# ICD-10 113 Cause List         106070 non-null object
# ICD-10 113 Cause List Code    106070 non-null object
# Year                          106070 non-null float64
# Ten-Year Age Groups           106070 non-null object
# Gender                        106070 non-null object
# Deaths                        106070 non-null float64
# Population                    106070 non-null object
# Crude Rate                    106070 non-null object
# dtypes: float64(2), object(7)
# memory usage: 5.3+ MB

# %%
frame_no_nan4.head(2)
# Out:
#                 Census Region  \
# 0  Census Region 1: Northeast
# 1  Census Region 1: Northeast
#
#                                ICD-10 113 Cause List  \
# 0  Certain other intestinal infections (A04,A07-A09)
# 1  Certain other intestinal infections (A04,A07-A09)
#
#   ICD-10 113 Cause List Code    Year Ten-Year Age Groups  Gender  Deaths  \
# 0                  GR113-003  1999.0         65-74 years  Female    24.0
# 1                  GR113-003  1999.0         65-74 years    Male    20.0
#
#   Population Crude Rate
# 0    2112718        1.1
# 1    1677845        1.2

# %%
frame_no_nan4.reset_index(drop=True, inplace=True)

# %%
frame_no_nan4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106070 entries, 0 to 106069
# Data columns (total 9 columns):
# Census Region                 106070 non-null object
# ICD-10 113 Cause List         106070 non-null object
# ICD-10 113 Cause List Code    106070 non-null object
# Year                          106070 non-null float64
# Ten-Year Age Groups           106070 non-null object
# Gender                        106070 non-null object
# Deaths                        106070 non-null float64
# Population                    106070 non-null object
# Crude Rate                    106070 non-null object
# dtypes: float64(2), object(7)
# memory usage: 4.5+ MB

# %%
frame_no_nan5 = frame_no_nan4.copy()

# %%
# Rename Column Header (indexes) with inplace flag
frame_no_nan5.rename(columns={'Census Region':'Region', 'Ten-Year Age Groups':'Age',
                              'ICD-10 113 Cause List':'ICD-10_Cause', 'ICD-10 113 Cause List Code': 'ICD-10_Code',
                             'Crude Rate':'Death_Rate'}, inplace=True)

# %%
frame_no_nan5['Death_Rate'] = pd.to_numeric(frame_no_nan5.Death_Rate) 
frame_no_nan5['Population'] = pd.to_numeric(frame_no_nan5.Population)

# %%
frame_no_nan5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106070 entries, 0 to 106069
# Data columns (total 9 columns):
# Region          106070 non-null object
# ICD-10_Cause    106070 non-null object
# ICD-10_Code     106070 non-null object
# Year            106070 non-null float64
# Age             106070 non-null object
# Gender          106070 non-null object
# Deaths          106070 non-null float64
# Population      106070 non-null int64
# Death_Rate      106070 non-null float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 5.3+ MB

# %%
frame_no_nan5.head(2)
# Out:
#                        Region  \
# 0  Census Region 1: Northeast
# 1  Census Region 1: Northeast
#
#                                         ICD-10_Cause ICD-10_Code    Year  \
# 0  Certain other intestinal infections (A04,A07-A09)   GR113-003  1999.0
# 1  Certain other intestinal infections (A04,A07-A09)   GR113-003  1999.0
#
#            Age  Gender  Deaths  Population  Death_Rate
# 0  65-74 years  Female    24.0     2112718         1.1
# 1  65-74 years    Male    20.0     1677845         1.2

# %%
# Export of data - progress - nulls, extra columns removed, columns (indexes) renamed
frame_no_nan5.to_csv('data/death1999_2018v5.csv', encoding='utf-8')

# %%
# Deep copy dataframe before re-indexing and melting
frame_no_nan6 = frame_no_nan5.copy()

# %%
frame_no_nan6.set_index(['Region','Year','Age','Gender'], inplace=True)

# %%
frame_no_nan6.head(10)
# Out:
#                                                                                            ICD-10_Cause  \
# Region                     Year   Age         Gender
# Census Region 1: Northeast 1999.0 65-74 years Female  Certain other intestinal infections (A04,A07-A09)
#                                               Male    Certain other intestinal infections (A04,A07-A09)
#                                   75-84 years Female  Certain other intestinal infections (A04,A07-A09)
#                                               Male    Certain other intestinal infections (A04,A07-A09)
#                                   85+ years   Female  Certain other intestinal infections (A04,A07-A09)
#                                               Male    Certain other intestinal infections (A04,A07-A09)
#                            2000.0 65-74 years Female  Certain other intestinal infections (A04,A07-A09)
# ...

# %%
frame_no_nan6.reset_index()
# Out:
#                             Region    Year          Age  Gender  \
# 0       Census Region 1: Northeast  1999.0  65-74 years  Female
# 1       Census Region 1: Northeast  1999.0  65-74 years    Male
# 2       Census Region 1: Northeast  1999.0  75-84 years  Female
# 3       Census Region 1: Northeast  1999.0  75-84 years    Male
# 4       Census Region 1: Northeast  1999.0    85+ years  Female
# ...                            ...     ...          ...     ...
# 106065       Census Region 4: West  2018.0  65-74 years    Male
# 106066       Census Region 4: West  2018.0  75-84 years  Female
# 106067       Census Region 4: West  2018.0  75-84 years    Male
# 106068       Census Region 4: West  2018.0    85+ years  Female
# 106069       Census Region 4: West  2018.0    85+ years    Male
#
#                                              ICD-10_Cause ICD-10_Code  Deaths  \
# 0       Certain other intestinal infections (A04,A07-A09)   GR113-003    24.0
# ...

# %%
frame_no_nan6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 106070 entries, (Census Region 1: Northeast, 1999.0, 65-74 years, Female) to (Census Region 4: West, 2018.0, 85+ years, Male)
# Data columns (total 5 columns):
# ICD-10_Cause    106070 non-null object
# ICD-10_Code     106070 non-null object
# Deaths          106070 non-null float64
# Population      106070 non-null int64
# Death_Rate      106070 non-null float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 3.6+ MB

# %%
frame6_pvt = frame_no_nan6.pivot_table(index=['Region', 'Year','Gender','ICD-10_Cause','ICD-10_Code'], 
                                columns='Age',
                                values='Death_Rate')
# ,'Population','Death_Rate'

# %%
frame6_pvt.head(6)
# Out:
# Age                                                                                                      1-4 years  \
# Region                     Year   Gender ICD-10_Cause                                       ICD-10_Code
# Census Region 1: Northeast 1999.0 Female #Accidents (unintentional injuries) (V01-X59,Y8... GR113-112          6.0
#                                          #Acute bronchitis and bronchiolitis (J20-J21)      GR113-080          NaN
#                                          #Alzheimer disease (G30)                           GR113-052          NaN
#                                          #Anemias (D50-D64)                                 GR113-045          NaN
#                                          #Aortic aneurysm and dissection (I71)              GR113-073          NaN
#                                          #Assault (homicide) (*U01-*U02,X85-Y09,Y87.1)      GR113-127          2.1
#
# ...

# %%
frame6_pvt.reset_index()
# Out:
# Age                        Region    Year  Gender  \
# 0      Census Region 1: Northeast  1999.0  Female
# 1      Census Region 1: Northeast  1999.0  Female
# 2      Census Region 1: Northeast  1999.0  Female
# 3      Census Region 1: Northeast  1999.0  Female
# 4      Census Region 1: Northeast  1999.0  Female
# ...                           ...     ...     ...
# 16759       Census Region 4: West  2018.0    Male
# 16760       Census Region 4: West  2018.0    Male
# 16761       Census Region 4: West  2018.0    Male
# 16762       Census Region 4: West  2018.0    Male
# 16763       Census Region 4: West  2018.0    Male
#
# Age                                         ICD-10_Cause ICD-10_Code  \
# 0      #Accidents (unintentional injuries) (V01-X59,Y...   GR113-112
# 1          #Acute bronchitis and bronchiolitis (J20-J21)   GR113-080
# 2                               #Alzheimer disease (G30)   GR113-052
# 3                                     #Anemias (D50-D64)   GR113-045
# ...

# %%
frame6_pvt.to_csv('data/death1999_2018pivot6.csv', encoding='utf-8')

# %%
frame6_pvt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 16764 entries, (Census Region 1: Northeast, 1999.0, Female, #Accidents (unintentional injuries) (V01-X59,Y85-Y86), GR113-112) to (Census Region 4: West, 2018.0, Male, Water, air and space, and other and unspecified transport accidents and their sequelae (V90-V99,Y85), GR113-116)
# Data columns (total 11 columns):
# 1-4 years      2285 non-null float64
# 15-24 years    5466 non-null float64
# 25-34 years    8486 non-null float64
# 35-44 years    11470 non-null float64
# 45-54 years    13638 non-null float64
# 5-14 years     3105 non-null float64
# 55-64 years    14769 non-null float64
# 65-74 years    15025 non-null float64
# 75-84 years    15052 non-null float64
# 85+ years      14018 non-null float64
# < 1 year       2756 non-null float64
# dtypes: float64(11)
# memory usage: 1.5+ MB

# %%
selected = frame6_pvt.loc['Census Region 1: Northeast', 1999.0]

# %%
frame6_pvt.head(7)
# Out:
# Age                                                                                                      1-4 years  \
# Region                     Year   Gender ICD-10_Cause                                       ICD-10_Code
# Census Region 1: Northeast 1999.0 Female #Accidents (unintentional injuries) (V01-X59,Y8... GR113-112          6.0
#                                          #Acute bronchitis and bronchiolitis (J20-J21)      GR113-080          NaN
#                                          #Alzheimer disease (G30)                           GR113-052          NaN
#                                          #Anemias (D50-D64)                                 GR113-045          NaN
#                                          #Aortic aneurysm and dissection (I71)              GR113-073          NaN
#                                          #Assault (homicide) (*U01-*U02,X85-Y09,Y87.1)      GR113-127          2.1
# ...

# %%
# Out:
# Age                                                                    1-4 years  \
# Gender ICD-10_Cause                                       ICD-10_Code
# Female #Accidents (unintentional injuries) (V01-X59,Y8... GR113-112          6.0
#        #Acute bronchitis and bronchiolitis (J20-J21)      GR113-080          NaN
#        #Alzheimer disease (G30)                           GR113-052          NaN
#        #Anemias (D50-D64)                                 GR113-045          NaN
#        #Aortic aneurysm and dissection (I71)              GR113-073          NaN
#
# Age                                                                    15-24 years  \
# Gender ICD-10_Cause                                       ICD-10_Code
# Female #Accidents (unintentional injuries) (V01-X59,Y8... GR113-112           14.2
#        #Acute bronchitis and bronchiolitis (J20-J21)      GR113-080            NaN
#        #Alzheimer disease (G30)                           GR113-052            NaN
# ...
